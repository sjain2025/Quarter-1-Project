# %% [markdown]
# <a href="https://colab.research.google.com/github/sjain2025/Quarter-1-Project/blob/main/Q1_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/Student_Performance_Data.csv")

# %%
data.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#    GradeClass
# 0           2
# 1           1
# 2           4
# 3           3
# ...

# %%
def min_max_normalize(df, exclude_col=-1):
    normalized_df = df.copy()
    columns_to_normalize = normalized_df.columns[:exclude_col] if exclude_col < 0 else normalized_df.columns[:-1]
    normalized_df[columns_to_normalize] = (normalized_df[columns_to_normalize] - normalized_df[columns_to_normalize].min()) / (normalized_df[columns_to_normalize].max() - normalized_df[columns_to_normalize].min())
    return normalized_df

# %%
data = min_max_normalize(data)

# %%
data.head()
# Out:
#         Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0  0.666667     1.0   0.000000               0.50         0.992773  0.241379
# 1  1.000000     0.0   0.000000               0.25         0.771270  0.000000
# 2  0.000000     0.0   0.666667               0.75         0.210718  0.896552
# 3  0.666667     1.0   0.000000               0.75         0.501965  0.482759
# 4  0.666667     1.0   0.000000               0.50         0.233840  0.586207
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0       1.0             0.50              0.0     0.0    1.0           0.0
# 1       0.0             0.25              0.0     0.0    0.0           0.0
# 2       0.0             0.50              0.0     0.0    0.0           0.0
# 3       0.0             0.75              1.0     0.0    0.0           0.0
# 4       1.0             0.75              0.0     0.0    0.0           0.0
#
#    GradeClass
# 0           2
# 1           1
# ...

# %%
gpa_mapping = {
    0: 'zero',
    1: 'one',
    2: 'two',
    3: 'three',
    4: 'four'
}

data['GradeClass'] = data['GradeClass'].map(gpa_mapping)

# %%
data.head()
# Out:
#         Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0  0.666667     1.0   0.000000               0.50         0.992773  0.241379
# 1  1.000000     0.0   0.000000               0.25         0.771270  0.000000
# 2  0.000000     0.0   0.666667               0.75         0.210718  0.896552
# 3  0.666667     1.0   0.000000               0.75         0.501965  0.482759
# 4  0.666667     1.0   0.000000               0.50         0.233840  0.586207
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0       1.0             0.50              0.0     0.0    1.0           0.0
# 1       0.0             0.25              0.0     0.0    0.0           0.0
# 2       0.0             0.50              0.0     0.0    0.0           0.0
# 3       0.0             0.75              1.0     0.0    0.0           0.0
# 4       1.0             0.75              0.0     0.0    0.0           0.0
#
#   GradeClass
# 0        two
# 1        one
# ...

# %%
data.to_csv('/content/Dataset.csv', index=False)

# %%
len(data) # number of instances
# Out:
# 2392

# %%
data.to_csv('/content/GPA_Dataset.csv', index=False)

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, temp_data = train_test_split(normalized_data, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# %%
print("Training set size:", train_data.shape)
print("Validation set size:", val_data.shape)
print("Testing set size:", test_data.shape)
# Out:
# Training set size: (1674, 13)
# Validation set size: (359, 13)
# Testing set size: (359, 13)

# %%
X_train = train_data.iloc[:, :-1]
Y_train = train_data.iloc[:, -1]

X_val = val_data.iloc[:, :-1]
Y_val = val_data.iloc[:, -1]

X_test = test_data.iloc[:, :-1]
Y_test = test_data.iloc[:, -1]

# %%
X_train.to_csv('/content/X_train.csv', index=False)
Y_train.to_csv('/content/Y_train.csv', index=False)
X_val.to_csv('/content/X_val.csv', index=False)
Y_val.to_csv('/content/Y_val.csv', index=False)
X_test.to_csv('/content/X_test.csv', index=False)
Y_test.to_csv('/content/Y_test.csv', index=False)
